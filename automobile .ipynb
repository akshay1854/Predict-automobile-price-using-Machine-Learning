# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('AutoData (1).csv')

# %%
df.head()
# Out:
#    symboling                      make fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %%
df.dtypes
# Out:
# symboling             int64
# make                 object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# symboling           0
# make                0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
df['make'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
CompanyName = df['make'].apply(lambda x : x.split(' ')[0])
df.insert(3,"CompanyName",CompanyName)
df.head()
# Out:
#    symboling                      make fueltype  CompanyName aspiration  \
# 0          3        alfa-romero giulia      gas  alfa-romero        std
# 1          3       alfa-romero stelvio      gas  alfa-romero        std
# 2          1  alfa-romero Quadrifoglio      gas  alfa-romero        std
# 3          2               audi 100 ls      gas         audi        std
# 4          2                audi 100ls      gas         audi        std
#
#   doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0        two  convertible        rwd          front       88.6  ...
# 1        two  convertible        rwd          front       88.6  ...
# 2        two    hatchback        rwd          front       94.5  ...
# 3       four        sedan        fwd          front       99.8  ...
# 4       four        sedan        4wd          front       99.4  ...
#
#    enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# ...

# %%
df.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
df['CompanyName']=df['CompanyName'].replace({'maxda':'mazda','Nissan':'nissan','porcshce':'porsche','toyouta':'toyota','vokswagen':'volkswagen','vw':'volkswagen'})

# %%
df.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
#

# %%
print('The Average Car Price')
sns.barplot(x="CompanyName", y="price", data=df)
# Out:
# The Average Car Price

# %%
f, ax = plt.subplots(figsize=(20,8))
sns.set(font_scale = 5)
print('The Average Car Price')
c = sns.barplot(x="CompanyName", y="price", data=df)
for item in c.get_xticklabels():
    item.set_rotation(45)
# Out:
# The Average Car Price

# %%
sns.set(font_scale = 3)
sns.countplot(df['fueltype'])

# %%
f, ax = plt.subplots(figsize=(20,8))

sns.set(font_scale = 3)
c=sns.countplot(df['CompanyName'])
for item in c.get_xticklabels():
    item.set_rotation(90)

# %%
f, ax = plt.subplots(figsize=(15,8))

sns.set(font_scale = 3)
c=sns.countplot(df['carbody'])
for item in c.get_xticklabels():
    item.set_rotation(90)

# %%
f, ax = plt.subplots(figsize=(10,8))

sns.set(font_scale = 3)
c=sns.countplot(df['drivewheel'])
for item in c.get_xticklabels():
    item.set_rotation(90)

# %%
f, ax = plt.subplots(figsize=(10,8))

sns.set(font_scale = 3)
c=sns.countplot(df['fuelsystem'])
for item in c.get_xticklabels():
    item.set_rotation(90)

# %%
f, ax = plt.subplots(figsize=(20,8))

sns.set(font_scale = 3)
c=sns.countplot(df['enginetype'])
for item in c.get_xticklabels():
    item.set_rotation(90)

# %%
f, ax = plt.subplots(figsize=(15,8))

sns.set(font_scale = 2)
c=sns.countplot(df['doornumber'])
for item in c.get_xticklabels():
    item.set_rotation(90)

f, ax = plt.subplots(figsize=(15,8))

sns.set(font_scale = 2)
c=sns.countplot(df['aspiration'])
for item in c.get_xticklabels():
    item.set_rotation(90)

f, ax = plt.subplots(figsize=(20,8))

sns.set(font_scale = 3)
c=sns.countplot(df['enginelocation'])
for item in c.get_xticklabels():
    item.set_rotation(90)

# %%
#Numeric data

# %%
df.head()
# Out:
#    symboling                      make fueltype  CompanyName aspiration  \
# 0          3        alfa-romero giulia      gas  alfa-romero        std
# 1          3       alfa-romero stelvio      gas  alfa-romero        std
# 2          1  alfa-romero Quadrifoglio      gas  alfa-romero        std
# 3          2               audi 100 ls      gas         audi        std
# 4          2                audi 100ls      gas         audi        std
#
#   doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0        two  convertible        rwd          front       88.6  ...
# 1        two  convertible        rwd          front       88.6  ...
# 2        two    hatchback        rwd          front       94.5  ...
# 3       four        sedan        fwd          front       99.8  ...
# 4       four        sedan        4wd          front       99.4  ...
#
#    enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# ...

# %%
f, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = df['wheelbase'],y=df['price'],data = df)

f, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = df['boreratio'],y=df['price'],data = df)

f, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = df['stroke'],y=df['price'],data = df)

f, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = df['compressionratio'],y=df['price'],data = df)


f, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = df['peakrpm'],y=df['price'],data = df)

f, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = df['citympg'],y=df['price'],data = df)

f, ax = plt.subplots(figsize=(10,6))
sns.regplot(x = df['highwaympg'],y=df['price'],data = df)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

df['fueltype'] = le.fit_transform(df['fueltype'])
df['CompanyName'] = le.fit_transform(df['CompanyName'])
df['aspiration'] = le.fit_transform(df['aspiration'])
df['doornumber'] = le.fit_transform(df['doornumber'])
df['carbody'] = le.fit_transform(df['carbody'])
df['drivewheel'] = le.fit_transform(df['drivewheel'])
df['enginelocation'] = le.fit_transform(df['enginelocation'])
df['fuelsystem'] = le.fit_transform(df['fuelsystem'])
df['enginetype'] = le.fit_transform(df['enginetype'])
df['cylindernumber'] = le.fit_transform(df['cylindernumber'])

# %%
df.head()
# Out:
#    symboling                      make  fueltype  CompanyName  aspiration  \
# 0          3        alfa-romero giulia         1            0           0
# 1          3       alfa-romero stelvio         1            0           0
# 2          1  alfa-romero Quadrifoglio         1            0           0
# 3          2               audi 100 ls         1            1           0
# 4          2                audi 100ls         1            1           0
#
#    doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# 0           1        0           2               0       88.6  ...
# 1           1        0           2               0       88.6  ...
# 2           1        2           2               0       94.5  ...
# 3           0        3           1               0       99.8  ...
# 4           0        3           0               0       99.4  ...
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# ...

# %%
 df = df.drop(['make'],axis= 1)

# %%
df.corr()
# Out:
#                   symboling  fueltype  CompanyName  aspiration  doornumber  \
# symboling          1.000000  0.194311    -0.092793   -0.059866    0.664073
# fueltype           0.194311  1.000000    -0.055049   -0.401397    0.191491
# CompanyName       -0.092793 -0.055049     1.000000    0.011326   -0.150465
# aspiration        -0.059866 -0.401397     0.011326    1.000000   -0.031792
# doornumber         0.664073  0.191491    -0.150465   -0.031792    1.000000
# carbody           -0.596135 -0.147853     0.101473    0.063028   -0.680358
# drivewheel        -0.041671 -0.132257    -0.056639    0.066465    0.098954
# enginelocation     0.212471  0.040070     0.054410   -0.057191    0.137757
# wheelbase         -0.531954 -0.308346    -0.013288    0.257611   -0.447357
# carlength         -0.357612 -0.212679     0.030733    0.234539   -0.398568
# carwidth          -0.232919 -0.233880    -0.103779    0.300567   -0.207168
# ...

# %%
plt.figure(figsize=(20,20))
sns.set(font_scale = 1.1)
sns.heatmap(df.corr(),annot=True,cmap='RdBu_r')

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

print('rain data \n',x)
print('test data \n',y)
# Out:
# rain data
#       symboling  fueltype  CompanyName  aspiration  doornumber  carbody  \
# 0            3         1            0           0           1        0
# 1            3         1            0           0           1        0
# 2            1         1            0           0           1        2
# 3            2         1            1           0           0        3
# 4            2         1            1           0           0        3
# ..         ...       ...          ...         ...         ...      ...
# 200         -1         1           21           0           0        3
# 201         -1         1           21           1           0        3
# 202         -1         1           21           0           0        3
# 203         -1         0           21           1           0        3
# 204         -1         1           21           1           0        3
#
#      drivewheel  enginelocation  wheelbase  carlength  ...  cylindernumber  \
# ...

# %% [markdown]
# ## Train an test split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ## Important feature

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = x_train.columns
vif['VIF'] = [variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#             Features      VIF
# 10          carwidth  6622.23
# 8          wheelbase  3224.73
# 9          carlength  2842.55
# 11         carheight  1405.74
# 1           fueltype   832.68
# 19  compressionratio   668.58
# 23        highwaympg   565.32
# 22           citympg   548.51
# 12        curbweight   456.90
# 21           peakrpm   348.33
# 17         boreratio   342.17
# 18            stroke   201.21
# 20        horsepower   199.00
# 15        enginesize   191.38
# 5            carbody    35.69
# 14    cylindernumber    24.05
# 6         drivewheel    15.58
# 13        enginetype    15.36
# 16        fuelsystem     9.74
# 2        CompanyName     7.67
# 4         doornumber     5.13
# 3         aspiration     4.99
# 0          symboling     4.01
# 7     enginelocation     2.27

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
model = lr.fit(x_train,y_train)

# %%
y_hat = model.predict(x_test)

# %%
model.score(x_train,y_train)
# Out:
# 0.9164115239310963

# %%
print(y_test)
print(y_hat)
# Out:
# 52      6795.0
# 181    15750.0
# 5      15250.0
# 18      5151.0
# 188     9995.0
# 170    11199.0
# 76      5389.0
# 154     7898.0
# 104    17199.0
# 33      6529.0
# 12     20970.0
# 129    31400.5
# 55     10945.0
# 66     18344.0
# 45      8916.5
# 169     9989.0
# 130     9295.0
# 7      18920.0
# 37      7895.0
# 152     6488.0
# 80      9959.0
# 111    15580.0
# 131     9895.0
# 171    11549.0
# 179    15998.0
# 138     5118.0
# 156     6938.0
# 113    16695.0
# 161     8358.0
# 89      5499.0
# 183     7975.0
# 193    12290.0
# 125    22018.0
# 173     8948.0
# 92      6849.0
# 16     41315.0
# 189    11595.0
# 136    18150.0
# 22      6377.0
# 74     45400.0
# 44      8916.5
# Name: price, dtype: float64
# [ 6215.19763712 17129.67849292 14310.58365483  1817.44714773
#   9710.75795407 13106.27292213  6934.53022498  4472.07222113
#  20342.27184199  7959.66352182 16267.65337812 27230.89225579
#  10544.70685539 13875.55431112  7612.47992197 11665.93425017
# ...

# %%
from sklearn.metrics import r2_score 
r2_score(y_test, y_hat)
# Out:
# 0.8149327846571359

# %%
fig = plt.figure()
plt.scatter(y_test,y_hat)

# %% [markdown]
# # find fetures by RFE

# %%
from sklearn.feature_selection import RFE
lm = LinearRegression()
lm.fit(x_train,y_train)
rfe = RFE(lm, 20)
rfe = rfe.fit(x_train, y_train)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass n_features_to_select=20 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "

# %%
list(zip(x_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('symboling', True, 1),
#  ('fueltype', True, 1),
#  ('CompanyName', True, 1),
#  ('aspiration', True, 1),
#  ('doornumber', True, 1),
#  ('carbody', True, 1),
#  ('drivewheel', True, 1),
#  ('enginelocation', True, 1),
#  ('wheelbase', True, 1),
#  ('carlength', True, 1),
#  ('carwidth', True, 1),
#  ('carheight', True, 1),
#  ('curbweight', False, 4),
#  ('enginetype', False, 2),
#  ('cylindernumber', True, 1),
#  ('enginesize', True, 1),
#  ('fuelsystem', True, 1),
#  ('boreratio', True, 1),
#  ('stroke', True, 1),
#  ('compressionratio', True, 1),
#  ('horsepower', True, 1),
#  ('peakrpm', False, 5),
#  ('citympg', False, 3),
#  ('highwaympg', True, 1)]

# %%
X_train_rfe = x_train[x_train.columns[rfe.support_]]
print(X_train_rfe)
x_test_rfe=x_test[x_test.columns[rfe.support_]]
# Out:
#      symboling  fueltype  CompanyName  aspiration  doornumber  carbody  \
# 4            2         1            1           0           0        3
# 71          -1         1            3           0           0        3
# 134          3         1           17           0           1        2
# 145          0         1           18           1           0        3
# 122          1         1           14           0           0        3
# ..         ...       ...          ...         ...         ...      ...
# 67          -1         0            3           1           0        3
# 192          0         0           20           1           0        3
# 117          0         1           13           1           0        3
# 47           0         1            8           0           0        3
# 172          2         1           19           0           1        0
#
#      drivewheel  enginelocation  wheelbase  carlength  carwidth  carheight  \
# ...

# %%
b = lm.fit(X_train_rfe,y_train)

# %%
lm.score(X_train_rfe,y_train)
# Out:
# 0.9109226050052712

# %%
y_pred = b.predict(x_test_rfe)
r2_score(y_test,y_pred )
# Out:
# 0.8259197851451734

# %%
import statsmodels.api as sm
model1= sm.OLS(y,x).fit()
print(model1.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.971
# Model:                            OLS   Adj. R-squared (uncentered):              0.967
# Method:                 Least Squares   F-statistic:                              255.1
# Date:                Sat, 02 Jan 2021   Prob (F-statistic):                   3.53e-126
# Time:                        17:12:27   Log-Likelihood:                         -1904.7
# No. Observations:                 205   AIC:                                      3857.
# Df Residuals:                     181   BIC:                                      3937.
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
